# %%
import pandas as pd
import numpy as np
import os
import json
import glob
import re
from matplotlib import pyplot as plt
from monty.serialization import loadfn
from sklearn.metrics import r2_score 
from scipy import stats

# %% [markdown]
# ## Creating New Data File

# %%
data_dir = "./DeltaQFastCharge/"
file_list = glob.glob(os.path.join(data_dir, '*.json'))
file_list[:5]
# Out:
# ['./DeltaQFastCharge\\LFP_15C_0-100_0.5-1C_a_CH00_features_DeltaQFastCharge.json',
#  './DeltaQFastCharge\\LFP_15C_0-100_0.5-1C_a_CH01_features_DeltaQFastCharge.json',
#  './DeltaQFastCharge\\LFP_15C_0-100_0.5-1C_a_CH02_features_DeltaQFastCharge.json',
#  './DeltaQFastCharge\\LFP_15C_0-100_0.5-1C_a_CH03_features_DeltaQFastCharge.json',
#  './DeltaQFastCharge\\LFP_15C_0-100_0.5-1C_a_CH04_features_DeltaQFastCharge.json']

# %%
# data_dir = "./DeltaQFastCharge/"
# file_list = glob.glob(os.path.join(data_dir, '*.json'))

delta_df = pd.DataFrame()
for f in file_list:
    with open(f) as fp:
        data = json.load(fp)
        for k in data['X'].keys():
            data['X'][k] = data['X'][k][0]
        delta_df = delta_df.append(pd.Series(data['X']), ignore_index=True)
delta_df.head()
# Out:
#    abs_first_discharge_capacity_difference_cycles_2:100  \
# 0                                          -3.309824
# 1                                          -3.019408
# 2                                          -2.312774
# 3                                          -2.677882
# 4                                          -2.005443
#
#    abs_kurtosis_discharge_capacity_difference_cycles_2:100  \
# 0                                           1.867028
# 1                                           2.349816
# 2                                           1.694375
# 3                                           1.495850
# 4                                           0.393445
#
#    abs_mean_discharge_capacity_difference_cycles_2:100  \
# 0                                          -2.742859
# 1                                          -2.648706
# 2                                          -1.917594
# 3                                          -2.076420
# 4                                          -1.682799
#
#    abs_min_discharge_capacity_difference_cycles_2:100  \
# 0                                          -0.446806
# 1                                          -0.208776
# 2                                          -0.195631
# 3                                          -0.631730
# 4                                          -0.189399
#
#    abs_skew_discharge_capacity_difference_cycles_2:100  \
# 0                                           0.584775
# 1                                           0.993881
# 2                                           0.655882
# 3                                           0.057256
# 4                                          -0.220132
#
#    abs_variance_discharge_capacity_difference_cycles_2:100  \
# 0                                          -3.166992
# 1                                          -3.056759
# 2                                          -2.478396
# 3                                          -2.981589
# 4                                          -1.291194
#
#    charge_time_cycles_1:5  discharge_capacity_cycle_100  \
# 0             5760.000000                         1.032
# 1             5785.600098                         1.042
# 2             5811.200195                         1.030
# 3             5785.600098                         1.025
# 4             5785.600098                         1.059
#
#    discharge_capacity_cycle_2  integrated_time_temperature_cycles_1:100  ...  \
# 0                       1.030                             306697.588291  ...
# 1                       1.040                             296427.402899  ...
# 2                       1.030                             262556.750559  ...
# 3                       1.029                             268508.727464  ...
# 4                       1.067                             614925.496456  ...
#
#    intercept_discharge_capacity_cycle_number_91:100  \
# 0                                          1.032000
# 1                                          1.042000
# 2                                          1.030000
# 3                                          1.025000
# 4                                          1.068364
#
#    internal_resistance_cycle_2  internal_resistance_difference_cycles_2:100  \
# 0                          NaN                                          NaN
# 1                          NaN                                          NaN
# 2                          NaN                                          NaN
# 3                          NaN                                          NaN
# 4                          NaN                                          NaN
#
#    max_discharge_capacity_difference  max_temperature_cycles_1:100  \
# 0                              1.035                     18.459000
# 1                              1.043                     16.705999
# 2                              1.029                     20.877001
# 3                              1.026                     22.084999
# 4                              1.074                     25.669001
#
#    min_internal_resistance_cycles_2:100  min_temperature_cycles_1:100  \
# 0                                   NaN                     15.160000
# 1                                   NaN                     15.281000
# 2                                   NaN                     15.107000
# 3                                   NaN                     15.306000
# 4                                   NaN                     24.084999
#
#    nominal_capacity_by_median  slope_discharge_capacity_cycle_number_2:100  \
# 0                       1.033                                    -0.000595
# 1                       1.044                                    -0.000603
# 2                       1.031                                    -0.000596
# 3                       1.028                                    -0.000626
# 4                       1.067                                    -0.000724
#
#    slope_discharge_capacity_cycle_number_91:100
# 0                                  1.217792e-17
# 1                                 -5.691578e-18
# 2                                  1.727324e-17
# 3                                  1.943125e-18
# 4                                 -9.696970e-05
#
# [5 rows x 21 columns]

# %%
delta_df = delta_df.drop(columns=['internal_resistance_cycle_2', 'internal_resistance_difference_cycles_2:100', 'min_internal_resistance_cycles_2:100'], axis=0)
delta_df.shape
# Out:
# (30, 18)

# %%
delta_df.isna().sum(axis=0)
# Out:
# abs_first_discharge_capacity_difference_cycles_2:100       0
# abs_kurtosis_discharge_capacity_difference_cycles_2:100    0
# abs_mean_discharge_capacity_difference_cycles_2:100        0
# abs_min_discharge_capacity_difference_cycles_2:100         0
# abs_skew_discharge_capacity_difference_cycles_2:100        0
# abs_variance_discharge_capacity_difference_cycles_2:100    0
# charge_time_cycles_1:5                                     0
# discharge_capacity_cycle_100                               0
# discharge_capacity_cycle_2                                 0
# integrated_time_temperature_cycles_1:100                   0
# intercept_discharge_capacity_cycle_number_2:100            0
# intercept_discharge_capacity_cycle_number_91:100           0
# max_discharge_capacity_difference                          0
# max_temperature_cycles_1:100                               1
# min_temperature_cycles_1:100                               1
# nominal_capacity_by_median                                 0
# slope_discharge_capacity_cycle_number_2:100                0
# slope_discharge_capacity_cycle_number_91:100               0
# dtype: int64

# %%
data_dir2 = "./TrajectoryFastCharge/"
file_list = glob.glob(os.path.join(data_dir2, '*.json'))

traj_df = pd.DataFrame()
for f in file_list:
    with open(f) as fp:
        data = json.load(fp)
        traj_df = traj_df.append(pd.Series(data['X']).apply(lambda x: x[0]), ignore_index=True)

# %%
traj_df.head()
# Out:
#    capacity_0.8  capacity_0.83  capacity_0.86  capacity_0.89  capacity_0.92  \
# 0        4550.0         4550.0         4550.0         4550.0          506.0
# 1        3552.0         3552.0         3552.0         3552.0         3552.0
# 2        3760.0         3760.0         3760.0         3760.0          506.0
# 3        3753.0         3753.0         3753.0         3753.0          506.0
# 4        3049.0         3049.0         3049.0         3049.0          207.0
#
#    capacity_0.95  capacity_0.98
# 0          506.0          506.0
# 1          506.0          506.0
# 2          506.0          506.0
# 3          506.0          506.0
# 4          207.0          207.0

# %%
full_df = pd.merge(delta_df,traj_df, left_index=True, right_index=True)
full_df.head()
# Out:
#    abs_first_discharge_capacity_difference_cycles_2:100  \
# 0                                          -3.309824
# 1                                          -3.019408
# 2                                          -2.312774
# 3                                          -2.677882
# 4                                          -2.005443
#
#    abs_kurtosis_discharge_capacity_difference_cycles_2:100  \
# 0                                           1.867028
# 1                                           2.349816
# 2                                           1.694375
# 3                                           1.495850
# 4                                           0.393445
#
#    abs_mean_discharge_capacity_difference_cycles_2:100  \
# 0                                          -2.742859
# 1                                          -2.648706
# 2                                          -1.917594
# 3                                          -2.076420
# 4                                          -1.682799
#
#    abs_min_discharge_capacity_difference_cycles_2:100  \
# 0                                          -0.446806
# 1                                          -0.208776
# 2                                          -0.195631
# 3                                          -0.631730
# 4                                          -0.189399
#
#    abs_skew_discharge_capacity_difference_cycles_2:100  \
# 0                                           0.584775
# 1                                           0.993881
# 2                                           0.655882
# 3                                           0.057256
# 4                                          -0.220132
#
#    abs_variance_discharge_capacity_difference_cycles_2:100  \
# 0                                          -3.166992
# 1                                          -3.056759
# 2                                          -2.478396
# 3                                          -2.981589
# 4                                          -1.291194
#
#    charge_time_cycles_1:5  discharge_capacity_cycle_100  \
# 0             5760.000000                         1.032
# 1             5785.600098                         1.042
# 2             5811.200195                         1.030
# 3             5785.600098                         1.025
# 4             5785.600098                         1.059
#
#    discharge_capacity_cycle_2  integrated_time_temperature_cycles_1:100  ...  \
# 0                       1.030                             306697.588291  ...
# 1                       1.040                             296427.402899  ...
# 2                       1.030                             262556.750559  ...
# 3                       1.029                             268508.727464  ...
# 4                       1.067                             614925.496456  ...
#
#    nominal_capacity_by_median  slope_discharge_capacity_cycle_number_2:100  \
# 0                       1.033                                    -0.000595
# 1                       1.044                                    -0.000603
# 2                       1.031                                    -0.000596
# 3                       1.028                                    -0.000626
# 4                       1.067                                    -0.000724
#
#    slope_discharge_capacity_cycle_number_91:100  capacity_0.8  capacity_0.83  \
# 0                                  1.217792e-17        4550.0         4550.0
# 1                                 -5.691578e-18        3552.0         3552.0
# 2                                  1.727324e-17        3760.0         3760.0
# 3                                  1.943125e-18        3753.0         3753.0
# 4                                 -9.696970e-05        3049.0         3049.0
#
#    capacity_0.86  capacity_0.89  capacity_0.92  capacity_0.95  capacity_0.98
# 0         4550.0         4550.0          506.0          506.0          506.0
# 1         3552.0         3552.0         3552.0          506.0          506.0
# 2         3760.0         3760.0          506.0          506.0          506.0
# 3         3753.0         3753.0          506.0          506.0          506.0
# 4         3049.0         3049.0          207.0          207.0          207.0
#
# [5 rows x 25 columns]

# %%
full_df.to_csv("LFPBatteries.csv", index=False)

# %% [markdown]
# ## Creating Original Data File

# %%
#d_dir = '/../Toyota/features/DeltaQFastCharge' # Directory for DeltaQFastCharge
d_dir = 'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge' # Directory for DeltaQFastCharge
t_dir = 'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge' # Directory for TrajectoryFastCharge
#t_dir = './Toyota/features/TrajectoryFastCharge' # Directory for TrajectoryFastCharge

# %%
def getListOfFiles(dirName):
    listOfFile = os.listdir(dirName)
    allFiles = list()
    for entry in listOfFile:
        fullPath = os.path.join(dirName, entry)
        if ".json" in fullPath:
            allFiles.append(fullPath)
    return allFiles

# %% [markdown]
# Getting Features

# %%
d_list = getListOfFiles(d_dir)
print(len(d_list))
d_list
# Out:
# 139
# ['C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000000_CH19_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000001_CH16_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000001_CH30_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000001_CH38_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000002_CH10_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000002_CH18_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000002_CH2_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000002_CH34_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000002_CH42_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000002_CH47_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000002_CH7_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000003_CH39_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000003_CH40_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000004_CH1_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000004_CH2_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000004_CH3_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000005_CH18_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000006_CH11_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000006_CH19_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000006_CH27_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000006_CH35_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000006_CH3_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000006_CH43_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000006_CH48_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000006_CH8_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000007_CH24_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000007_CH39_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000008_CH47_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000008_CH48_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000009_CH4_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000009_CH7_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000009_CH8_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000010_CH44_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000011_CH26_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000012_CH13_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000012_CH15_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000012_CH21_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000012_CH23_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000012_CH29_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000012_CH37_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000012_CH45_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000012_CH5_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000013_CH13_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000013_CH14_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000014_CH23_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000014_CH24_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000015_CH12_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000015_CH14_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000015_CH20_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000015_CH22_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000015_CH28_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000015_CH36_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000015_CH44_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000015_CH4_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000016_CH17_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000017_CH17_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000017_CH1_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000017_CH25_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000017_CH33_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000017_CH41_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000017_CH46_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000017_CH6_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000017_CH9_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000018_CH18_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000019_CH29_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000019_CH30_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000020_CH23_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000021_CH28_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000022_CH24_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000023_CH37_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000023_CH38_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000024_CH45_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000025_CH7_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000026_CH5_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000026_CH6_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000027_CH31_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000028_CH19_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000028_CH20_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000029_CH10_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000029_CH9_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000030_CH30_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000031_CH9_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000032_CH22_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000033_CH14_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000034_CH27_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000035_CH12_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000036_CH48_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000037_CH21_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000037_CH22_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000038_CH13_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000039_CH27_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000039_CH28_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000040_CH32_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000041_CH10_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000042_CH36_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000043_CH16_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000044_CH11_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000044_CH12_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000045_CH1_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000045_CH2_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000045_CH3_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000046_CH31_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000046_CH32_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000047_CH21_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000048_CH43_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000048_CH44_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000049_CH37_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000050_CH32_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000050_CH40_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000051_CH15_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000051_CH16_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000052_CH41_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000053_CH42_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000054_CH15_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000055_CH20_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000056_CH11_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000057_CH35_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000057_CH36_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000058_CH45_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000058_CH46_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000059_CH33_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000060_CH29_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000061_CH43_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000062_CH47_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000063_CH5_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000063_CH6_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000064_CH39_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000065_CH33_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000065_CH34_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000066_CH25_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000066_CH26_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000067_CH41_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000067_CH42_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000068_CH38_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000069_CH25_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000070_CH46_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000071_CH40_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000072_CH34_features_DeltaQFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/DeltaQFastCharge\\FastCharge_000073_CH35_features_DeltaQFastCharge.json']

# %%
new_names = []
for file in d_list:
    new_names.append(re.findall("CH(.*?)\_f", file)[0])
# new_names

# %%
d_df = pd.DataFrame()
for file in d_list:
    with open(file) as data_file:    
        data = json.load(data_file)
        data_df = pd.json_normalize(data)
        d_df = pd.concat([d_df,data_df])
d_df.reset_index(drop=True,inplace=True)
d_df['bat_num'] = new_names
d_df.head()
# Out:
#           @module            @class  \
# 0  beep.featurize  DeltaQFastCharge
# 1  beep.featurize  DeltaQFastCharge
# 2  beep.featurize  DeltaQFastCharge
# 3  beep.featurize  DeltaQFastCharge
# 4  beep.featurize  DeltaQFastCharge
#
#                                                 name      @version  \
# 0  /mnt/c/Users/sjrt1/Documents/School/Winter2021...  2021.1.11.15
# 1  /mnt/c/Users/sjrt1/Documents/School/Winter2021...  2021.1.11.15
# 2  /mnt/c/Users/sjrt1/Documents/School/Winter2021...  2021.1.11.15
# 3  /mnt/c/Users/sjrt1/Documents/School/Winter2021...  2021.1.11.15
# 4  /mnt/c/Users/sjrt1/Documents/School/Winter2021...  2021.1.11.15
#
#   X.discharge_capacity_cycle_2 X.max_discharge_capacity_difference  \
# 0                  [1.0454259]                [0.8891461000000003]
# 1         [1.0620247999999999]               [0.48970650000000004]
# 2                  [1.0678786]                [0.4961450999999999]
# 3                  [1.0512739]               [0.49011190000000004]
# 4                  [1.0665728]               [0.47571469999999993]
#
#   X.discharge_capacity_cycle_100 X.integrated_time_temperature_cycles_1:100  \
# 0                    [1.0331815]                        [231072.4263671875]
# 1                    [1.0439155]                       [149767.85131961218]
# 2                     [1.054091]                        [205315.4877278646]
# 3           [1.0341983000000001]                        [159799.4890051929]
# 4                    [1.0695093]                        [146029.5250360061]
#
#   X.charge_time_cycles_1:5  \
# 0      [614.4000244140625]
# 1      [563.2000122070312]
# 2      [614.4000244140625]
# 3      [563.2000122070312]
# 4      [614.4000244140625]
#
#   X.abs_min_discharge_capacity_difference_cycles_2:100  ...  \
# 0                              [-1.1444158302992298]    ...
# 1                              [-1.2773591296554208]    ...
# 2                              [-1.3752393675218624]    ...
# 3                              [-1.2430890844325302]    ...
# 4                               [-1.640443517452452]    ...
#
#   X.internal_resistance_difference_cycles_2:100 X.nominal_capacity_by_median  \
# 0                      [-0.0010415539145469666]                   [1.047977]
# 1                       [0.0003414759412407875]                 [1.06011365]
# 2                      [0.00024036318063735962]                 [1.06736225]
# 3                      [0.00042933784425258636]                 [1.05098615]
# 4                      [-0.0001586293801665306]                  [1.0708095]
#
#   metadata.barcode                                  metadata.protocol  \
# 0   el150800440551        2017-06-30_tests\20170630-4_4C_55per_6C.sdu
# 1   el150800737229  2018-04-12_batch8\20180412-3_7C_31per_5_9C_new...
# 2   el150800737366  2018-04-12_batch8\20180412-3_7C_31per_5_9C_new...
# 3   el150800737234  2018-04-12_batch8\20180412-3_7C_31per_5_9C_new...
# 4   el150800737329  2018-04-12_batch8\20180412-5C_67per_4C_newstru...
#
#   metadata.channel_id metadata.parameters.init_pred_cycle  \
# 0                  18                                  10
# 1                  15                                  10
# 2                  29                                  10
# 3                  37                                  10
# 4                   9                                  10
#
#   metadata.parameters.mid_pred_cycle metadata.parameters.final_pred_cycle  \
# 0                                 91                                  100
# 1                                 91                                  100
# 2                                 91                                  100
# 3                                 91                                  100
# 4                                 91                                  100
#
#   metadata.parameters.n_nominal_cycles bat_num
# 0                                   40      19
# 1                                   40      16
# 2                                   40      30
# 3                                   40      38
# 4                                   40      10
#
# [5 rows x 33 columns]

# %%
batches = []
for i in d_df['metadata.protocol']:
    if '2017-05' in i:
        batches.append('b1')
    elif '2017-06' in i:
        batches.append('b2')
    elif '2018-04' in i:
        batches.append('b3')
# batches

# %%
d_df['batches'] = batches
d_df['bat_name'] = d_df['batches'] + 'c' + d_df['bat_num']

# %%
d_df['bat_name']
# Out:
# 0      b2c19
# 1      b3c16
# 2      b3c30
# 3      b3c38
# 4      b3c10
#        ...
# 134    b2c25
# 135    b2c46
# 136    b2c40
# 137    b2c34
# 138    b2c35
# Name: bat_name, Length: 139, dtype: object

# %% [markdown]
# Response variable data

# %%
t_list = getListOfFiles(t_dir)
print(len(t_list))
t_list
# Out:
# 139
# ['C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000000_CH19_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000001_CH16_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000001_CH30_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000001_CH38_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000002_CH10_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000002_CH18_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000002_CH2_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000002_CH34_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000002_CH42_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000002_CH47_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000002_CH7_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000003_CH39_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000003_CH40_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000004_CH1_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000004_CH2_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000004_CH3_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000005_CH18_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000006_CH11_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000006_CH19_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000006_CH27_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000006_CH35_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000006_CH3_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000006_CH43_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000006_CH48_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000006_CH8_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000007_CH24_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000007_CH39_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000008_CH47_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000008_CH48_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000009_CH4_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000009_CH7_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000009_CH8_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000010_CH44_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000011_CH26_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000012_CH13_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000012_CH15_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000012_CH21_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000012_CH23_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000012_CH29_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000012_CH37_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000012_CH45_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000012_CH5_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000013_CH13_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000013_CH14_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000014_CH23_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000014_CH24_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000015_CH12_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000015_CH14_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000015_CH20_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000015_CH22_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000015_CH28_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000015_CH36_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000015_CH44_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000015_CH4_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000016_CH17_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000017_CH17_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000017_CH1_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000017_CH25_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000017_CH33_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000017_CH41_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000017_CH46_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000017_CH6_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000017_CH9_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000018_CH18_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000019_CH29_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000019_CH30_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000020_CH23_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000021_CH28_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000022_CH24_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000023_CH37_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000023_CH38_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000024_CH45_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000025_CH7_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000026_CH5_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000026_CH6_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000027_CH31_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000028_CH19_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000028_CH20_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000029_CH10_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000029_CH9_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000030_CH30_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000031_CH9_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000032_CH22_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000033_CH14_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000034_CH27_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000035_CH12_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000036_CH48_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000037_CH21_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000037_CH22_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000038_CH13_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000039_CH27_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000039_CH28_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000040_CH32_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000041_CH10_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000042_CH36_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000043_CH16_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000044_CH11_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000044_CH12_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000045_CH1_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000045_CH2_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000045_CH3_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000046_CH31_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000046_CH32_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000047_CH21_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000048_CH43_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000048_CH44_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000049_CH37_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000050_CH32_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000050_CH40_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000051_CH15_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000051_CH16_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000052_CH41_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000053_CH42_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000054_CH15_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000055_CH20_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000056_CH11_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000057_CH35_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000057_CH36_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000058_CH45_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000058_CH46_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000059_CH33_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000060_CH29_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000061_CH43_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000062_CH47_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000063_CH5_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000063_CH6_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000064_CH39_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000065_CH33_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000065_CH34_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000066_CH25_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000066_CH26_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000067_CH41_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000067_CH42_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000068_CH38_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000069_CH25_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000070_CH46_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000071_CH40_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000072_CH34_features_TrajectoryFastCharge.json',
#  'C:/Users/mattm/Documents/CalPoly/DATA 451/Toyota/features/TrajectoryFastCharge\\FastCharge_000073_CH35_features_TrajectoryFastCharge.json']

# %%
t_df = pd.DataFrame()
for file in t_list:
    with open(file) as data_file:    
        data = json.load(data_file)
        data_df = pd.json_normalize(data)
        t_df = pd.concat([t_df,data_df])
t_df.reset_index(inplace=True)
t_df.head()
# Out:
#    index         @module                @class  \
# 0      0  beep.featurize  TrajectoryFastCharge
# 1      0  beep.featurize  TrajectoryFastCharge
# 2      0  beep.featurize  TrajectoryFastCharge
# 3      0  beep.featurize  TrajectoryFastCharge
# 4      0  beep.featurize  TrajectoryFastCharge
#
#                                                 name      @version  \
# 0  /mnt/c/Users/sjrt1/Documents/School/Winter2021...  2021.1.11.15
# 1  /mnt/c/Users/sjrt1/Documents/School/Winter2021...  2021.1.11.15
# 2  /mnt/c/Users/sjrt1/Documents/School/Winter2021...  2021.1.11.15
# 3  /mnt/c/Users/sjrt1/Documents/School/Winter2021...  2021.1.11.15
# 4  /mnt/c/Users/sjrt1/Documents/School/Winter2021...  2021.1.11.15
#
#   X.capacity_0.98 X.capacity_0.95 X.capacity_0.92 X.capacity_0.89  \
# 0           [127]           [269]           [376]           [423]
# 1           [125]           [276]           [426]           [528]
# 2           [774]           [774]           [774]           [774]
# 3           [543]           [543]           [543]           [543]
# 4          [1011]          [1011]          [1011]          [1011]
#
#   X.capacity_0.86 X.capacity_0.83 X.capacity_0.8 metadata.barcode  \
# 0           [449]           [467]          [483]   el150800440551
# 1           [613]           [668]          [668]   el150800737229
# 2           [774]           [774]          [774]   el150800737366
# 3           [543]           [543]          [543]   el150800737234
# 4          [1011]          [1011]         [1011]   el150800737329
#
#                                    metadata.protocol  metadata.channel_id  \
# 0        2017-06-30_tests\20170630-4_4C_55per_6C.sdu                   18
# 1  2018-04-12_batch8\20180412-3_7C_31per_5_9C_new...                   15
# 2  2018-04-12_batch8\20180412-3_7C_31per_5_9C_new...                   29
# 3  2018-04-12_batch8\20180412-3_7C_31per_5_9C_new...                   37
# 4  2018-04-12_batch8\20180412-5C_67per_4C_newstru...                    9
#
#    metadata.parameters.thresh_max_cap  metadata.parameters.thresh_min_cap  \
# 0                                0.98                                0.78
# 1                                0.98                                0.78
# 2                                0.98                                0.78
# 3                                0.98                                0.78
# 4                                0.98                                0.78
#
#    metadata.parameters.interval_cap
# 0                              0.03
# 1                              0.03
# 2                              0.03
# 3                              0.03
# 4                              0.03

# %%
df_full = d_df.merge(t_df, left_index=True, right_index=True)

# Making values not stored as lists
for column in df_full.columns:
    if "X." in column:
        df_full[column] = df_full[column].apply(lambda x: x[0])

#df_full.sort_values(by=['bat_name'],inplace=True)
df_full.reset_index(inplace=True)
df_full
# Out:
#      level_0       @module_x          @class_x  \
# 0          0  beep.featurize  DeltaQFastCharge
# 1          1  beep.featurize  DeltaQFastCharge
# 2          2  beep.featurize  DeltaQFastCharge
# 3          3  beep.featurize  DeltaQFastCharge
# 4          4  beep.featurize  DeltaQFastCharge
# ..       ...             ...               ...
# 134      134  beep.featurize  DeltaQFastCharge
# 135      135  beep.featurize  DeltaQFastCharge
# 136      136  beep.featurize  DeltaQFastCharge
# 137      137  beep.featurize  DeltaQFastCharge
# 138      138  beep.featurize  DeltaQFastCharge
#
#                                                 name_x    @version_x  \
# 0    /mnt/c/Users/sjrt1/Documents/School/Winter2021...  2021.1.11.15
# 1    /mnt/c/Users/sjrt1/Documents/School/Winter2021...  2021.1.11.15
# 2    /mnt/c/Users/sjrt1/Documents/School/Winter2021...  2021.1.11.15
# 3    /mnt/c/Users/sjrt1/Documents/School/Winter2021...  2021.1.11.15
# 4    /mnt/c/Users/sjrt1/Documents/School/Winter2021...  2021.1.11.15
# ..                                                 ...           ...
# 134  /mnt/c/Users/sjrt1/Documents/School/Winter2021...  2021.1.11.15
# 135  /mnt/c/Users/sjrt1/Documents/School/Winter2021...  2021.1.11.15
# 136  /mnt/c/Users/sjrt1/Documents/School/Winter2021...  2021.1.11.15
# 137  /mnt/c/Users/sjrt1/Documents/School/Winter2021...  2021.1.11.15
# 138  /mnt/c/Users/sjrt1/Documents/School/Winter2021...  2021.1.11.15
#
#      X.discharge_capacity_cycle_2  X.max_discharge_capacity_difference  \
# 0                        1.045426                             0.889146
# 1                        1.062025                             0.489707
# 2                        1.067879                             0.496145
# 3                        1.051274                             0.490112
# 4                        1.066573                             0.475715
# ..                            ...                                  ...
# 134                      1.068216                             0.887755
# 135                      1.066163                             0.886750
# 136                      1.074378                             0.888332
# 137                      1.075889                             0.892131
# 138                      1.064950                             0.885654
#
#      X.discharge_capacity_cycle_100  \
# 0                          1.033181
# 1                          1.043915
# 2                          1.054091
# 3                          1.034198
# 4                          1.069509
# ..                              ...
# 134                        1.076756
# 135                        1.073273
# 136                        1.086167
# 137                        1.084460
# 138                        1.074855
#
#      X.integrated_time_temperature_cycles_1:100  X.charge_time_cycles_1:5  \
# 0                                 231072.426367                614.400024
# 1                                 149767.851320                563.200012
# 2                                 205315.487728                614.400024
# 3                                 159799.489005                563.200012
# 4                                 146029.525036                614.400024
# ..                                          ...                       ...
# 134                               233369.177230                588.799988
# 135                               231731.725590                640.000000
# 136                               228614.760124                614.400024
# 137                               234874.822253                588.799988
# 138                               235214.380884                588.799988
#
#      ...  X.capacity_0.89  X.capacity_0.86  X.capacity_0.83  X.capacity_0.8  \
# 0    ...              423              449              467             483
# 1    ...              528              613              668             668
# 2    ...              774              774              774             774
# 3    ...              543              543              543             543
# 4    ...             1011             1011             1011            1011
# ..   ...              ...              ...              ...             ...
# 134  ...              250              483              503             522
# 135  ...              443              462              480             497
# 136  ...              420              435              449             464
# 137  ...              472              491              509             527
# 138  ...              458              476              493             510
#
#      metadata.barcode_y                                metadata.protocol_y  \
# 0        el150800440551        2017-06-30_tests\20170630-4_4C_55per_6C.sdu
# 1        el150800737229  2018-04-12_batch8\20180412-3_7C_31per_5_9C_new...
# 2        el150800737366  2018-04-12_batch8\20180412-3_7C_31per_5_9C_new...
# 3        el150800737234  2018-04-12_batch8\20180412-3_7C_31per_5_9C_new...
# 4        el150800737329  2018-04-12_batch8\20180412-5C_67per_4C_newstru...
# ..                  ...                                                ...
# 134      el150800460610      2017-06-30_tests\20170630-4_9C_61per_4_5C.sdu
# 135      el150800460613        2017-06-30_tests\20170630-6C_4per_4_75C.sdu
# 136      el150800460627      2017-06-30_tests\20170630-5_6C_58per_3_5C.sdu
# 137      el150800460641        2017-06-30_tests\20170630-5_2C_58per_4C.sdu
# 138      el150800460492      2017-06-30_tests\20170630-5_2C_66per_3_5C.sdu
#
#      metadata.channel_id_y  metadata.parameters.thresh_max_cap  \
# 0                       18                                0.98
# 1                       15                                0.98
# 2                       29                                0.98
# 3                       37                                0.98
# 4                        9                                0.98
# ..                     ...                                 ...
# 134                     24                                0.98
# 135                     45                                0.98
# 136                     39                                0.98
# 137                     33                                0.98
# 138                     34                                0.98
#
#      metadata.parameters.thresh_min_cap  metadata.parameters.interval_cap
# 0                                  0.78                              0.03
# 1                                  0.78                              0.03
# 2                                  0.78                              0.03
# 3                                  0.78                              0.03
# 4                                  0.78                              0.03
# ..                                  ...                               ...
# 134                                0.78                              0.03
# 135                                0.78                              0.03
# 136                                0.78                              0.03
# 137                                0.78                              0.03
# 138                                0.78                              0.03
#
# [139 rows x 54 columns]

# %%
df_full.to_csv("OldDataFastCharge.csv", index=False)
