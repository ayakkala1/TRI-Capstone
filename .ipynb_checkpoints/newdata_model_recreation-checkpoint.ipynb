# %%
import os
import glob
import json
import pandas as pd
import numpy as np
import requests
import re

os.environ['BEEP_ENV'] = 'dev'

# %% [markdown]
# New battery_archive data

# %% [markdown]
# Structuring from time series a

# %%
d_dir = "./NewData/DeltaQFastCharge/"
t_dir = "./NewData/TrajectoryFastCharge/"

# %%
# path = "E:/Data/TRI/NewData/"
# d_dir = path + "DeltaQFastCharge/"
# t_dir = path + "TrajectoryFastCharge/"

# %%
def getListOfFiles(dirName):
    listOfFile = os.listdir(dirName)
    allFiles = list()
    for entry in listOfFile:
        fullPath = os.path.join(dirName, entry)
        if ".json" in fullPath:
            allFiles.append(fullPath)
    return allFiles

# %%
d_list = getListOfFiles(d_dir)
print(len(d_list))
d_list
# Out:
# 30
# ['./NewData/DeltaQFastCharge/LFP_15C_0-100_0.5-1C_a_CH00_features_DeltaQFastCharge.json',
#  './NewData/DeltaQFastCharge/LFP_15C_0-100_0.5-1C_a_CH01_features_DeltaQFastCharge.json',
#  './NewData/DeltaQFastCharge/LFP_15C_0-100_0.5-1C_a_CH02_features_DeltaQFastCharge.json',
#  './NewData/DeltaQFastCharge/LFP_15C_0-100_0.5-1C_a_CH03_features_DeltaQFastCharge.json',
#  './NewData/DeltaQFastCharge/LFP_15C_0-100_0.5-1C_a_CH04_features_DeltaQFastCharge.json',
#  './NewData/DeltaQFastCharge/LFP_15C_0-100_0.5-1C_a_CH05_features_DeltaQFastCharge.json',
#  './NewData/DeltaQFastCharge/LFP_15C_0-100_0.5-1C_a_CH06_features_DeltaQFastCharge.json',
#  './NewData/DeltaQFastCharge/LFP_15C_0-100_0.5-1C_a_CH07_features_DeltaQFastCharge.json',
#  './NewData/DeltaQFastCharge/LFP_15C_0-100_0.5-1C_a_CH08_features_DeltaQFastCharge.json',
#  './NewData/DeltaQFastCharge/LFP_15C_0-100_0.5-1C_a_CH09_features_DeltaQFastCharge.json',
#  './NewData/DeltaQFastCharge/LFP_15C_0-100_0.5-1C_a_CH10_features_DeltaQFastCharge.json',
#  './NewData/DeltaQFastCharge/LFP_15C_0-100_0.5-1C_a_CH11_features_DeltaQFastCharge.json',
#  './NewData/DeltaQFastCharge/LFP_15C_0-100_0.5-1C_a_CH12_features_DeltaQFastCharge.json',
#  './NewData/DeltaQFastCharge/LFP_15C_0-100_0.5-1C_a_CH13_features_DeltaQFastCharge.json',
#  './NewData/DeltaQFastCharge/LFP_15C_0-100_0.5-1C_a_CH14_features_DeltaQFastCharge.json',
#  './NewData/DeltaQFastCharge/LFP_25C_20-80_0.5-0.5C_a_CH15_features_DeltaQFastCharge.json',
#  './NewData/DeltaQFastCharge/LFP_25C_20-80_0.5-0.5C_b_CH16_features_DeltaQFastCharge.json',
#  './NewData/DeltaQFastCharge/LFP_25C_20-80_0.5-0.5C_c_CH17_features_DeltaQFastCharge.json',
#  './NewData/DeltaQFastCharge/LFP_25C_20-80_0.5-0.5C_d_CH18_features_DeltaQFastCharge.json',
#  './NewData/DeltaQFastCharge/LFP_25C_20-80_0.5-3C_a_CH19_features_DeltaQFastCharge.json',
#  './NewData/DeltaQFastCharge/LFP_25C_40-60_0.5-0.5C_a_CH20_features_DeltaQFastCharge.json',
#  './NewData/DeltaQFastCharge/LFP_25C_40-60_0.5-0.5C_b_CH21_features_DeltaQFastCharge.json',
#  './NewData/DeltaQFastCharge/LFP_25C_40-60_0.5-3C_a_CH22_features_DeltaQFastCharge.json',
#  './NewData/DeltaQFastCharge/LFP_25C_40-60_0.5-3C_b_CH23_features_DeltaQFastCharge.json',
#  './NewData/DeltaQFastCharge/LFP_35C_0-100_0.5-1C_a_CH24_features_DeltaQFastCharge.json',
#  './NewData/DeltaQFastCharge/LFP_35C_0-100_0.5-1C_b_CH25_features_DeltaQFastCharge.json',
#  './NewData/DeltaQFastCharge/LFP_35C_0-100_0.5-1C_c_CH26_features_DeltaQFastCharge.json',
#  './NewData/DeltaQFastCharge/LFP_35C_0-100_0.5-1C_d_CH27_features_DeltaQFastCharge.json',
#  './NewData/DeltaQFastCharge/LFP_35C_0-100_0.5-2C_a_CH28_features_DeltaQFastCharge.json',
#  './NewData/DeltaQFastCharge/LFP_35C_0-100_0.5-2C_b_CH29_features_DeltaQFastCharge.json']

# %%
new_names = []
for file in d_list:
    new_names.append(re.findall("CH(.*?)\_f", file)[0])

# %%
d_df = pd.DataFrame()
for file in d_list:
    with open(file) as data_file:    
        data = json.load(data_file)
        data_df = pd.json_normalize(data)
        d_df = pd.concat([d_df,data_df])
d_df.reset_index(drop=True,inplace=True)
d_df['bat_num'] = new_names
d_df.head()
# Out:
#           @module            @class  \
# 0  beep.featurize  DeltaQFastCharge
# 1  beep.featurize  DeltaQFastCharge
# 2  beep.featurize  DeltaQFastCharge
# 3  beep.featurize  DeltaQFastCharge
# 4  beep.featurize  DeltaQFastCharge
#
#                                                 name      @version  \
# 0  C:\Users\mattm\Documents\CalPoly\DATA 451\Toyo...  2021.1.11.15
# 1  C:\Users\mattm\Documents\CalPoly\DATA 451\Toyo...  2021.1.11.15
# 2  C:\Users\mattm\Documents\CalPoly\DATA 451\Toyo...  2021.1.11.15
# 3  C:\Users\mattm\Documents\CalPoly\DATA 451\Toyo...  2021.1.11.15
# 4  C:\Users\mattm\Documents\CalPoly\DATA 451\Toyo...  2021.1.11.15
#
#   X.discharge_capacity_cycle_2 X.max_discharge_capacity_difference  \
# 0                       [1.03]                             [1.035]
# 1                       [1.04]                [1.0430000000000001]
# 2                       [1.03]                [1.0290000000000001]
# 3                      [1.029]                [1.0260000000000002]
# 4                      [1.067]                             [1.074]
#
#   X.discharge_capacity_cycle_100 X.integrated_time_temperature_cycles_1:100  \
# 0                        [1.032]                       [306697.58829142264]
# 1                        [1.042]                        [296427.4028991698]
# 2                         [1.03]                       [262556.75055948895]
# 3                        [1.025]                        [268508.7274637858]
# 4           [1.0590000000000002]                        [614925.4964558918]
#
#   X.charge_time_cycles_1:5  \
# 0                 [5760.0]
# 1       [5785.60009765625]
# 2        [5811.2001953125]
# 3       [5785.60009765625]
# 4       [5785.60009765625]
#
#   X.abs_min_discharge_capacity_difference_cycles_2:100  ...  \
# 0                             [-0.44680629485828904]    ...
# 1                             [-0.20877572651236104]    ...
# 2                             [-0.19563143967312835]    ...
# 3                              [-0.6317302807027921]    ...
# 4                              [-0.1893985483034041]    ...
#
#   X.internal_resistance_difference_cycles_2:100 X.nominal_capacity_by_median  \
# 0                                         [nan]                      [1.033]
# 1                                         [nan]                      [1.044]
# 2                                         [nan]                      [1.031]
# 3                                         [nan]                      [1.028]
# 4                                         [nan]                      [1.067]
#
#   metadata.barcode metadata.protocol metadata.channel_id  \
# 0             None              None                None
# 1             None              None                None
# 2             None              None                None
# 3             None              None                None
# 4             None              None                None
#
#   metadata.parameters.init_pred_cycle metadata.parameters.mid_pred_cycle  \
# 0                                  10                                 91
# 1                                  10                                 91
# 2                                  10                                 91
# 3                                  10                                 91
# 4                                  10                                 91
#
#   metadata.parameters.final_pred_cycle metadata.parameters.n_nominal_cycles  \
# 0                                  100                                   40
# 1                                  100                                   40
# 2                                  100                                   40
# 3                                  100                                   40
# 4                                  100                                   40
#
#   bat_num
# 0      00
# 1      01
# 2      02
# 3      03
# 4      04
#
# [5 rows x 33 columns]

# %%
t_list = getListOfFiles(t_dir)
print(len(t_list))
t_list
# Out:
# 30
# ['./NewData/TrajectoryFastCharge/LFP_15C_0-100_0.5-1C_a_CH00_features_TrajectoryFastCharge.json',
#  './NewData/TrajectoryFastCharge/LFP_15C_0-100_0.5-1C_a_CH01_features_TrajectoryFastCharge.json',
#  './NewData/TrajectoryFastCharge/LFP_15C_0-100_0.5-1C_a_CH02_features_TrajectoryFastCharge.json',
#  './NewData/TrajectoryFastCharge/LFP_15C_0-100_0.5-1C_a_CH03_features_TrajectoryFastCharge.json',
#  './NewData/TrajectoryFastCharge/LFP_15C_0-100_0.5-1C_a_CH04_features_TrajectoryFastCharge.json',
#  './NewData/TrajectoryFastCharge/LFP_15C_0-100_0.5-1C_a_CH05_features_TrajectoryFastCharge.json',
#  './NewData/TrajectoryFastCharge/LFP_15C_0-100_0.5-1C_a_CH06_features_TrajectoryFastCharge.json',
#  './NewData/TrajectoryFastCharge/LFP_15C_0-100_0.5-1C_a_CH07_features_TrajectoryFastCharge.json',
#  './NewData/TrajectoryFastCharge/LFP_15C_0-100_0.5-1C_a_CH08_features_TrajectoryFastCharge.json',
#  './NewData/TrajectoryFastCharge/LFP_15C_0-100_0.5-1C_a_CH09_features_TrajectoryFastCharge.json',
#  './NewData/TrajectoryFastCharge/LFP_15C_0-100_0.5-1C_a_CH10_features_TrajectoryFastCharge.json',
#  './NewData/TrajectoryFastCharge/LFP_15C_0-100_0.5-1C_a_CH11_features_TrajectoryFastCharge.json',
#  './NewData/TrajectoryFastCharge/LFP_15C_0-100_0.5-1C_a_CH12_features_TrajectoryFastCharge.json',
#  './NewData/TrajectoryFastCharge/LFP_15C_0-100_0.5-1C_a_CH13_features_TrajectoryFastCharge.json',
#  './NewData/TrajectoryFastCharge/LFP_15C_0-100_0.5-1C_a_CH14_features_TrajectoryFastCharge.json',
#  './NewData/TrajectoryFastCharge/LFP_15C_0-100_0.5-1C_a_CH15_features_TrajectoryFastCharge.json',
#  './NewData/TrajectoryFastCharge/LFP_15C_0-100_0.5-1C_a_CH16_features_TrajectoryFastCharge.json',
#  './NewData/TrajectoryFastCharge/LFP_15C_0-100_0.5-1C_a_CH17_features_TrajectoryFastCharge.json',
#  './NewData/TrajectoryFastCharge/LFP_15C_0-100_0.5-1C_a_CH18_features_TrajectoryFastCharge.json',
#  './NewData/TrajectoryFastCharge/LFP_15C_0-100_0.5-1C_a_CH19_features_TrajectoryFastCharge.json',
#  './NewData/TrajectoryFastCharge/LFP_15C_0-100_0.5-1C_a_CH20_features_TrajectoryFastCharge.json',
#  './NewData/TrajectoryFastCharge/LFP_15C_0-100_0.5-1C_a_CH21_features_TrajectoryFastCharge.json',
#  './NewData/TrajectoryFastCharge/LFP_15C_0-100_0.5-1C_a_CH22_features_TrajectoryFastCharge.json',
#  './NewData/TrajectoryFastCharge/LFP_15C_0-100_0.5-1C_a_CH23_features_TrajectoryFastCharge.json',
#  './NewData/TrajectoryFastCharge/LFP_15C_0-100_0.5-1C_a_CH24_features_TrajectoryFastCharge.json',
#  './NewData/TrajectoryFastCharge/LFP_15C_0-100_0.5-1C_a_CH25_features_TrajectoryFastCharge.json',
#  './NewData/TrajectoryFastCharge/LFP_15C_0-100_0.5-1C_a_CH26_features_TrajectoryFastCharge.json',
#  './NewData/TrajectoryFastCharge/LFP_15C_0-100_0.5-1C_a_CH27_features_TrajectoryFastCharge.json',
#  './NewData/TrajectoryFastCharge/LFP_15C_0-100_0.5-1C_a_CH28_features_TrajectoryFastCharge.json',
#  './NewData/TrajectoryFastCharge/LFP_15C_0-100_0.5-1C_a_CH29_features_TrajectoryFastCharge.json']

# %%
t_df = pd.DataFrame()
for file in t_list:
    with open(file) as data_file:    
        data = json.load(data_file)
        data_df = pd.json_normalize(data)
        t_df = pd.concat([t_df,data_df])
t_df.reset_index(inplace=True)
t_df.head()
# Out:
#    index         @module                @class  \
# 0      0  beep.featurize  TrajectoryFastCharge
# 1      0  beep.featurize  TrajectoryFastCharge
# 2      0  beep.featurize  TrajectoryFastCharge
# 3      0  beep.featurize  TrajectoryFastCharge
# 4      0  beep.featurize  TrajectoryFastCharge
#
#                                                 name      @version  \
# 0  C:\Users\mattm\Documents\CalPoly\DATA 451\Toyo...  2021.1.11.15
# 1  C:\Users\mattm\Documents\CalPoly\DATA 451\Toyo...  2021.1.11.15
# 2  C:\Users\mattm\Documents\CalPoly\DATA 451\Toyo...  2021.1.11.15
# 3  C:\Users\mattm\Documents\CalPoly\DATA 451\Toyo...  2021.1.11.15
# 4  C:\Users\mattm\Documents\CalPoly\DATA 451\Toyo...  2021.1.11.15
#
#   X.capacity_0.98 X.capacity_0.95 X.capacity_0.92 X.capacity_0.89  \
# 0         [506.0]         [506.0]         [506.0]        [4550.0]
# 1         [506.0]         [506.0]        [3552.0]        [3552.0]
# 2         [506.0]         [506.0]         [506.0]        [3760.0]
# 3         [506.0]         [506.0]         [506.0]        [3753.0]
# 4         [207.0]         [207.0]         [207.0]        [3049.0]
#
#   X.capacity_0.86 X.capacity_0.83 X.capacity_0.8 metadata.barcode  \
# 0        [4550.0]        [4550.0]       [4550.0]             None
# 1        [3552.0]        [3552.0]       [3552.0]             None
# 2        [3760.0]        [3760.0]       [3760.0]             None
# 3        [3753.0]        [3753.0]       [3753.0]             None
# 4        [3049.0]        [3049.0]       [3049.0]             None
#
#   metadata.protocol metadata.channel_id  metadata.parameters.thresh_max_cap  \
# 0              None                None                                0.98
# 1              None                None                                0.98
# 2              None                None                                0.98
# 3              None                None                                0.98
# 4              None                None                                0.98
#
#    metadata.parameters.thresh_min_cap  metadata.parameters.interval_cap
# 0                                0.78                              0.03
# 1                                0.78                              0.03
# 2                                0.78                              0.03
# 3                                0.78                              0.03
# 4                                0.78                              0.03

# %%
df_full = d_df.merge(t_df, left_index=True, right_index=True)

# Making values not stored as lists
for column in df_full.columns:
    if "X." in column:
        df_full[column] = df_full[column].apply(lambda x: x[0])

df_full.reset_index(inplace=True)
df_full
# Out:
#     level_0       @module_x          @class_x  \
# 0         0  beep.featurize  DeltaQFastCharge
# 1         1  beep.featurize  DeltaQFastCharge
# 2         2  beep.featurize  DeltaQFastCharge
# 3         3  beep.featurize  DeltaQFastCharge
# 4         4  beep.featurize  DeltaQFastCharge
# 5         5  beep.featurize  DeltaQFastCharge
# 6         6  beep.featurize  DeltaQFastCharge
# 7         7  beep.featurize  DeltaQFastCharge
# 8         8  beep.featurize  DeltaQFastCharge
# 9         9  beep.featurize  DeltaQFastCharge
# 10       10  beep.featurize  DeltaQFastCharge
# 11       11  beep.featurize  DeltaQFastCharge
# 12       12  beep.featurize  DeltaQFastCharge
# 13       13  beep.featurize  DeltaQFastCharge
# 14       14  beep.featurize  DeltaQFastCharge
# 15       15  beep.featurize  DeltaQFastCharge
# 16       16  beep.featurize  DeltaQFastCharge
# 17       17  beep.featurize  DeltaQFastCharge
# 18       18  beep.featurize  DeltaQFastCharge
# 19       19  beep.featurize  DeltaQFastCharge
# 20       20  beep.featurize  DeltaQFastCharge
# 21       21  beep.featurize  DeltaQFastCharge
# 22       22  beep.featurize  DeltaQFastCharge
# 23       23  beep.featurize  DeltaQFastCharge
# 24       24  beep.featurize  DeltaQFastCharge
# 25       25  beep.featurize  DeltaQFastCharge
# 26       26  beep.featurize  DeltaQFastCharge
# 27       27  beep.featurize  DeltaQFastCharge
# 28       28  beep.featurize  DeltaQFastCharge
# 29       29  beep.featurize  DeltaQFastCharge
#
#                                                name_x    @version_x  \
# 0   C:\Users\mattm\Documents\CalPoly\DATA 451\Toyo...  2021.1.11.15
# 1   C:\Users\mattm\Documents\CalPoly\DATA 451\Toyo...  2021.1.11.15
# 2   C:\Users\mattm\Documents\CalPoly\DATA 451\Toyo...  2021.1.11.15
# 3   C:\Users\mattm\Documents\CalPoly\DATA 451\Toyo...  2021.1.11.15
# 4   C:\Users\mattm\Documents\CalPoly\DATA 451\Toyo...  2021.1.11.15
# 5   C:\Users\mattm\Documents\CalPoly\DATA 451\Toyo...  2021.1.11.15
# 6   C:\Users\mattm\Documents\CalPoly\DATA 451\Toyo...  2021.1.11.15
# 7   C:\Users\mattm\Documents\CalPoly\DATA 451\Toyo...  2021.1.11.15
# 8   C:\Users\mattm\Documents\CalPoly\DATA 451\Toyo...  2021.1.11.15
# 9   C:\Users\mattm\Documents\CalPoly\DATA 451\Toyo...  2021.1.11.15
# 10  C:\Users\mattm\Documents\CalPoly\DATA 451\Toyo...  2021.1.11.15
# 11  C:\Users\mattm\Documents\CalPoly\DATA 451\Toyo...  2021.1.11.15
# 12  C:\Users\mattm\Documents\CalPoly\DATA 451\Toyo...  2021.1.11.15
# 13  C:\Users\mattm\Documents\CalPoly\DATA 451\Toyo...  2021.1.11.15
# 14  C:\Users\mattm\Documents\CalPoly\DATA 451\Toyo...  2021.1.11.15
# 15  C:\Users\mattm\Documents\CalPoly\DATA 451\Toyo...  2021.1.11.15
# 16  C:\Users\mattm\Documents\CalPoly\DATA 451\Toyo...  2021.1.11.15
# 17  C:\Users\mattm\Documents\CalPoly\DATA 451\Toyo...  2021.1.11.15
# 18  C:\Users\mattm\Documents\CalPoly\DATA 451\Toyo...  2021.1.11.15
# 19  C:\Users\mattm\Documents\CalPoly\DATA 451\Toyo...  2021.1.11.15
# 20  C:\Users\mattm\Documents\CalPoly\DATA 451\Toyo...  2021.1.11.15
# 21  C:\Users\mattm\Documents\CalPoly\DATA 451\Toyo...  2021.1.11.15
# 22  C:\Users\mattm\Documents\CalPoly\DATA 451\Toyo...  2021.1.11.15
# 23  C:\Users\mattm\Documents\CalPoly\DATA 451\Toyo...  2021.1.11.15
# 24  C:\Users\mattm\Documents\CalPoly\DATA 451\Toyo...  2021.1.11.15
# 25  C:\Users\mattm\Documents\CalPoly\DATA 451\Toyo...  2021.1.11.15
# 26  C:\Users\mattm\Documents\CalPoly\DATA 451\Toyo...  2021.1.11.15
# 27  C:\Users\mattm\Documents\CalPoly\DATA 451\Toyo...  2021.1.11.15
# 28  C:\Users\mattm\Documents\CalPoly\DATA 451\Toyo...  2021.1.11.15
# 29  C:\Users\mattm\Documents\CalPoly\DATA 451\Toyo...  2021.1.11.15
#
#     X.discharge_capacity_cycle_2  X.max_discharge_capacity_difference  \
# 0                          1.030                                1.035
# 1                          1.040                                1.043
# 2                          1.030                                1.029
# 3                          1.029                                1.026
# 4                          1.067                                1.074
# 5                          1.032                                1.032
# 6                          1.035                                1.038
# 7                          1.050                                1.048
# 8                          1.049                                1.048
# 9                          1.036                                1.027
# 10                         1.030                                1.027
# 11                         1.036                                1.031
# 12                         1.048                                1.034
# 13                         1.039                                1.027
# 14                         1.062                                1.044
# 15                         1.069                                0.385
# 16                         1.045                                0.453
# 17                         1.064                                0.461
# 18                         1.047                                0.451
# 19                         1.053                                0.002
# 20                         1.070                                0.003
# 21                         1.066                                0.003
# 22                         1.064                                0.003
# 23                         1.050                                0.003
# 24                         1.076                                1.067
# 25                         1.046                                1.031
# 26                         1.057                                1.047
# 27                         1.059                                1.050
# 28                         1.064                                1.053
# 29                         1.039                                1.029
#
#     X.discharge_capacity_cycle_100  \
# 0                            1.032
# 1                            1.042
# 2                            1.030
# 3                            1.025
# 4                            1.059
# 5                            1.029
# 6                            1.035
# 7                            1.048
# 8                            1.047
# 9                            1.030
# 10                           1.026
# 11                           1.024
# 12                           1.031
# 13                           1.021
# 14                           1.043
# 15                           0.551
# 16                           0.582
# 17                           0.589
# 18                           0.587
# 19                           0.660
# 20                           0.220
# 21                           0.220
# 22                           0.220
# 23                           0.220
# 24                           1.058
# 25                           1.027
# 26                           1.037
# 27                           1.042
# 28                           1.047
# 29                           1.021
#
#     X.integrated_time_temperature_cycles_1:100  X.charge_time_cycles_1:5  ...  \
# 0                                306697.588291               5760.000000  ...
# 1                                296427.402899               5785.600098  ...
# 2                                262556.750559               5811.200195  ...
# 3                                268508.727464               5785.600098  ...
# 4                                614925.496456               5785.600098  ...
# 5                                460906.194088               5785.600098  ...
# 6                                460296.723763               5785.600098  ...
# 7                                457406.060653               5785.600098  ...
# 8                                467247.932532               5785.600098  ...
# 9                                394481.761096               5811.200195  ...
# 10                                    0.000000               5785.600098  ...
# 11                               374946.338977               5811.200195  ...
# 12                               377107.872070               5760.000000  ...
# 13                               383545.417961               5785.600098  ...
# 14                               378827.355619               5785.600098  ...
# 15                               326905.490255               5824.000000  ...
# 16                               342046.127161               5824.000000  ...
# 17                               345449.769877               5888.000000  ...
# 18                               341275.267204               5824.000000  ...
# 19                               245992.996077               5824.000000  ...
# 20                               152024.337240               5824.000000  ...
# 21                               153234.505802               5824.000000  ...
# 22                               110629.903088               5824.000000  ...
# 23                               108479.438135               5824.000000  ...
# 24                               671446.618498               5862.399902  ...
# 25                               655294.596574               5862.399902  ...
# 26                               658224.979215               5862.399902  ...
# 27                               663203.989551               5836.799805  ...
# 28                               567987.983480               5862.399902  ...
# 29                               558202.225260               5862.399902  ...
#
#     X.capacity_0.89  X.capacity_0.86  X.capacity_0.83  X.capacity_0.8  \
# 0            4550.0           4550.0           4550.0          4550.0
# 1            3552.0           3552.0           3552.0          3552.0
# 2            3760.0           3760.0           3760.0          3760.0
# 3            3753.0           3753.0           3753.0          3753.0
# 4            3049.0           3049.0           3049.0          3049.0
# 5            3544.0           3544.0           3544.0          3544.0
# 6            3547.0           3547.0           3547.0          3547.0
# 7            3037.0           3037.0           3037.0          3037.0
# 8            3037.0           3037.0           3037.0          3037.0
# 9            3543.0           3543.0           3543.0          3543.0
# 10           4049.0           4049.0           4049.0          4049.0
# 11            207.0            207.0            207.0           207.0
# 12            207.0            207.0            207.0          4061.0
# 13            208.0            208.0            208.0           208.0
# 14            205.0            205.0            205.0          4061.0
# 15           7374.0           7374.0           7374.0          7374.0
# 16           7441.0           7441.0           7441.0          7441.0
# 17           5944.0           5944.0           5944.0          5944.0
# 18           6591.0           6591.0           6591.0          6591.0
# 19           2958.0           2958.0           2958.0          2958.0
# 20          19174.0          19174.0          19174.0         19174.0
# 21          18165.0          18165.0          18165.0         18165.0
# 22          12627.0          12627.0          12627.0         12627.0
# 23          11620.0          11620.0          11620.0         11620.0
# 24            257.0           3155.0           3155.0          3155.0
# 25            257.0            257.0           3341.0          3341.0
# 26            257.0            257.0           3341.0          3341.0
# 27            257.0            257.0           3797.0          3797.0
# 28            257.0            257.0           3855.0          3855.0
# 29            257.0            257.0            257.0          3597.0
#
#     metadata.barcode_y  metadata.protocol_y  metadata.channel_id_y  \
# 0                 None                 None                   None
# 1                 None                 None                   None
# 2                 None                 None                   None
# 3                 None                 None                   None
# 4                 None                 None                   None
# 5                 None                 None                   None
# 6                 None                 None                   None
# 7                 None                 None                   None
# 8                 None                 None                   None
# 9                 None                 None                   None
# 10                None                 None                   None
# 11                None                 None                   None
# 12                None                 None                   None
# 13                None                 None                   None
# 14                None                 None                   None
# 15                None                 None                   None
# 16                None                 None                   None
# 17                None                 None                   None
# 18                None                 None                   None
# 19                None                 None                   None
# 20                None                 None                   None
# 21                None                 None                   None
# 22                None                 None                   None
# 23                None                 None                   None
# 24                None                 None                   None
# 25                None                 None                   None
# 26                None                 None                   None
# 27                None                 None                   None
# 28                None                 None                   None
# 29                None                 None                   None
#
#     metadata.parameters.thresh_max_cap  metadata.parameters.thresh_min_cap  \
# 0                                 0.98                                0.78
# 1                                 0.98                                0.78
# 2                                 0.98                                0.78
# 3                                 0.98                                0.78
# 4                                 0.98                                0.78
# 5                                 0.98                                0.78
# 6                                 0.98                                0.78
# 7                                 0.98                                0.78
# 8                                 0.98                                0.78
# 9                                 0.98                                0.78
# 10                                0.98                                0.78
# 11                                0.98                                0.78
# 12                                0.98                                0.78
# 13                                0.98                                0.78
# 14                                0.98                                0.78
# 15                                0.98                                0.78
# 16                                0.98                                0.78
# 17                                0.98                                0.78
# 18                                0.98                                0.78
# 19                                0.98                                0.78
# 20                                0.98                                0.78
# 21                                0.98                                0.78
# 22                                0.98                                0.78
# 23                                0.98                                0.78
# 24                                0.98                                0.78
# 25                                0.98                                0.78
# 26                                0.98                                0.78
# 27                                0.98                                0.78
# 28                                0.98                                0.78
# 29                                0.98                                0.78
#
#     metadata.parameters.interval_cap
# 0                               0.03
# 1                               0.03
# 2                               0.03
# 3                               0.03
# 4                               0.03
# 5                               0.03
# 6                               0.03
# 7                               0.03
# 8                               0.03
# 9                               0.03
# 10                              0.03
# 11                              0.03
# 12                              0.03
# 13                              0.03
# 14                              0.03
# 15                              0.03
# 16                              0.03
# 17                              0.03
# 18                              0.03
# 19                              0.03
# 20                              0.03
# 21                              0.03
# 22                              0.03
# 23                              0.03
# 24                              0.03
# 25                              0.03
# 26                              0.03
# 27                              0.03
# 28                              0.03
# 29                              0.03
#
# [30 rows x 52 columns]

# %%
print(min(df_full['X.capacity_0.8']))
print(max(df_full['X.capacity_0.8']))
# Out:
# 207.0
# 19174.0

# %% [markdown]
# Model Receration

# %%
variance_model_features = 'X.abs_variance_discharge_capacity_difference_cycles_2:100'
discharge_model_features = ['X.abs_min_discharge_capacity_difference_cycles_2:100',
                            'X.abs_variance_discharge_capacity_difference_cycles_2:100',
                            'X.abs_skew_discharge_capacity_difference_cycles_2:100',
                            'X.abs_kurtosis_discharge_capacity_difference_cycles_2:100',
                            'X.discharge_capacity_cycle_2',
                            'X.max_discharge_capacity_difference'
                            ]
full_model_features = ['X.abs_min_discharge_capacity_difference_cycles_2:100',
                       'X.abs_variance_discharge_capacity_difference_cycles_2:100',
                       'X.slope_discharge_capacity_cycle_number_2:100',
                       'X.intercept_discharge_capacity_cycle_number_2:100',
                       'X.discharge_capacity_cycle_2',
                       'X.charge_time_cycles_1:5',
                       'X.integrated_time_temperature_cycles_1:100']
#                        'X.min_internal_resistance_cycles_2:100',
#                        'X.internal_resistance_difference_cycles_2:100']
y = 'X.capacity_0.8'

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_percentage_error
from sklearn.model_selection import KFold
from sklearn.utils import resample
from matplotlib import pyplot as plt

# %%
df_full.plot.scatter(x='X.abs_variance_discharge_capacity_difference_cycles_2:100', y = 'X.capacity_0.8')

# %%
# KFold 
splits = []
kf = KFold(n_splits=2,shuffle=True, random_state = 4)
for train_index, test_index in kf.split(df_full):
    splits.append((train_index,test_index))
    print("TRAIN:", train_index, "TEST:", test_index)
#     X_train, X_test = X[train_index], X[test_index]
#     y_train, y_test = y[train_index], y[test_index]
# Out:
# TRAIN: [ 1  2  4  5  7  8  9 13 14 18 22 23 24 26 27] TEST: [ 0  3  6 10 11 12 15 16 17 19 20 21 25 28 29]
# TRAIN: [ 0  3  6 10 11 12 15 16 17 19 20 21 25 28 29] TEST: [ 1  2  4  5  7  8  9 13 14 18 22 23 24 26 27]

# %%
splits
# Out:
# [(array([ 1,  2,  4,  5,  7,  8,  9, 13, 14, 18, 22, 23, 24, 26, 27]),
#   array([ 0,  3,  6, 10, 11, 12, 15, 16, 17, 19, 20, 21, 25, 28, 29])),
#  (array([ 0,  3,  6, 10, 11, 12, 15, 16, 17, 19, 20, 21, 25, 28, 29]),
#   array([ 1,  2,  4,  5,  7,  8,  9, 13, 14, 18, 22, 23, 24, 26, 27]))]

# %%
train_ind = splits[0][0]
test_ind = splits[0][1]

# %%
# Variance model
X_train_var = df_full.iloc[train_ind][[variance_model_features]]
y_train = df_full.iloc[train_ind][[y]]

X_test_var = df_full.iloc[test_ind][[variance_model_features]]
y_test = df_full.iloc[test_ind][[y]]

reg_var = LinearRegression().fit(X_train_var,y_train)
y_pred_train_var = reg_var.predict(X_train_var)
y_pred_test_var = reg_var.predict(X_test_var)

rmse_train_var = np.sqrt(mean_squared_error(y_train, y_pred_train_var))
rmse_test_var = np.sqrt(mean_squared_error(y_test, y_pred_test_var))
mape_train_var = mean_absolute_percentage_error(y_train, y_pred_train_var)
mape_test_var = mean_absolute_percentage_error(y_test, y_pred_test_var)

print("Variance Model")
print("Training RMSE: ", rmse_train_var)
print("Test RMSE: ", rmse_test_var)
print("Mean % Train Error: ", mape_train_var)
print("Mean % Test Error: ", mape_test_var)
# Out:
# Variance Model
# Training RMSE:  2546.458758586743
# Test RMSE:  5040.126778483995
# Mean % Train Error:  2.1842460993900454
# Mean % Test Error:  2.0236245907058086

# %%
# Variance model
max_var = y_test.max()[0]

plt.scatter(y_test, y_pred_test_var)
plt.plot([0, max_var], [0, max_var], color="red")
plt.xlabel("True Values")
plt.ylabel("Predicted Values")
plt.title("Variance Model Predicted vs. True Values")
# Out:
# Text(0.5, 1.0, 'Variance Model Predicted vs. True Values')

# %%
# discharge model
X_train_dis = df_full.iloc[train_ind][discharge_model_features]
X_train_dis = X_train_dis.replace([np.inf, -np.inf], np.nan)
X_train_dis.dropna(inplace = True)
X_train_dis_index = list(X_train_dis.index.values)

y_train = df_full.iloc[X_train_dis_index][[y]]

X_test_dis = df_full.iloc[test_ind][discharge_model_features]
X_test_dis = X_test_dis.replace([np.inf, -np.inf], np.nan)
X_test_dis.dropna(inplace = True)
X_test_dis_index = list(X_test_dis.index.values)

y_test = df_full.iloc[X_test_dis_index][[y]]

reg_dis = LinearRegression().fit(X_train_dis,y_train)
y_pred_train_dis = reg_dis.predict(X_train_dis)
y_pred_test_dis = reg_dis.predict(X_test_dis)

rmse_train_dis = np.sqrt(mean_squared_error(y_train, y_pred_train_dis))
rmse_test_dis = np.sqrt(mean_squared_error(y_test, y_pred_test_dis))
mape_train_dis = mean_absolute_percentage_error(y_train, y_pred_train_dis)
mape_test_dis = mean_absolute_percentage_error(y_test, y_pred_test_dis)

print("Discharge Model")
print("Training RMSE: ", np.sqrt(mean_squared_error(y_train, y_pred_train_dis)))
print("Test RMSE: ", np.sqrt(mean_squared_error(y_test, y_pred_test_dis)))
print("Mean % Train Error: ", mean_absolute_percentage_error(y_train, y_pred_train_dis))
print("Mean % Test Error: ", mean_absolute_percentage_error(y_test, y_pred_test_dis))
# Out:
# Discharge Model
# Training RMSE:  279.2704900908766
# Test RMSE:  2053.2180936398568
# Mean % Train Error:  0.18504585887872202
# Mean % Test Error:  0.9953781025219379

# %%
# Discharge model
max_dis = y_test.max()[0]

plt.scatter(y_test, y_pred_test_dis)
plt.plot([0, max_dis], [0, max_dis], color="red")
plt.xlabel("True Values")
plt.ylabel("Predicted Values")
plt.title("Discharge Model Predicted vs. True Values")
# Out:
# Text(0.5, 1.0, 'Discharge Model Predicted vs. True Values')

# %%
# full model
X_train_full = df_full.iloc[train_ind][full_model_features]
X_train_full.replace(-np.Inf, np.nan, inplace = True)
X_train_full.dropna(inplace = True)
X_train_full_index = list(X_train_full.index.values)

y_train = df_full.iloc[X_train_full_index][[y]]

X_test_full = df_full.iloc[test_ind][full_model_features]
X_test_full.replace(-np.Inf, np.nan, inplace = True)
X_test_full.dropna(inplace = True)
X_test_full_index = list(X_test_full.index.values)

y_test = df_full.iloc[X_test_full_index][[y]]

reg_full = LinearRegression().fit(X_train_full,y_train)
y_pred_train_full = reg_full.predict(X_train_full)
y_pred_test_full = reg_full.predict(X_test_full)

rmse_train_full = np.sqrt(mean_squared_error(y_train, y_pred_train_full))
rmse_test_full = np.sqrt(mean_squared_error(y_test, y_pred_test_full))
mape_train_full = mean_absolute_percentage_error(y_train, y_pred_train_full)
mape_test_full = mean_absolute_percentage_error(y_test, y_pred_test_full)

print("Full Model")
print("Training RMSE: ", np.sqrt(mean_squared_error(y_train, y_pred_train_full)))
print("Test RMSE: ", np.sqrt(mean_squared_error(y_test, y_pred_test_full)))
print("Mean % Train Error: ", mean_absolute_percentage_error(y_train, y_pred_train_full))
print("Mean % Test Error: ", mean_absolute_percentage_error(y_test, y_pred_test_full))
# Out:
# Full Model
# Training RMSE:  276.5983988261087
# Test RMSE:  1496.574382627428
# Mean % Train Error:  0.18567514955695955
# Mean % Test Error:  0.8350393287479783

# %%
# full model
max_full = y_test.max()[0]

plt.scatter(y_test, y_pred_test_full)
plt.plot([0, max_full], [0, max_full], color="red")
plt.xlabel("True Values")
plt.ylabel("Predicted Values")
plt.title("Full Model Predicted vs. True Values")
# Out:
# Text(0.5, 1.0, 'Full Model Predicted vs. True Values')

# %%
plt.hist(y_test)
plt.xlabel('X.capacity_0.8')
plt.ylabel('Frequency')
plt.title('Frequency of X.capacity_0.8')
# Out:
# Text(0.5, 1.0, 'Frequency of X.capacity_0.8')

# %%
# All columns in X_test_full
for feature in X_test_full.columns:
    plt.hist(X_test_full[feature])
    plt.xlabel(feature)
    plt.ylabel("Frequency")
    plt.title("Frequency of " + feature)
    plt.show()

# %%
metrics = pd.DataFrame(data = {"Model & Source": ["Variance (New)","Discharge (New)", "Full (New)"],
                               "Train RMSE": [rmse_train_var, rmse_train_dis, rmse_train_full],
                               "Test RMSE": [rmse_test_var, rmse_test_dis, rmse_test_full],
                               "Mean % Train Error": [mape_train_var, mape_train_dis, mape_train_full],
                               "Mean % Test Error": [mape_test_var, mape_test_dis, mape_test_full]})


for column in metrics.columns[1:]:
    ax = metrics.plot.bar(x='Model & Source', y=column, rot=0,
                         fontsize = 12, legend=False, figsize = (8,8),
                         color = ["y","b","r"])

    ax.set_xlabel("Model & Source", fontsize = 16)
    ax.set_ylabel(column, fontsize=16)
    ax.set_title(column + " Comparison", fontsize=16)
    plt.show()
